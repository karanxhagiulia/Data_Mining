# %%
# %matplotlib inline #si può saltare, è data semplicemente per ottimizzare il notebook, non utilizzarla MAI con python normale, solo per notebook

# %%
import matplotlib.pyplot as plt

import numpy as np
from numpy.random import rand

# %% [markdown]
# Per conoscere quali metodi che la classe che ho importato eredita, per esempio in plt, scrivo plt. e mi verrà l'elenco di ciò che viene importato

# %%
x = rand(1000)
y = rand(1000)

plt.scatter(x,y, color='green'); #puoi mettere gli argomenti che vuoi
#plt.show()

# %%
x = rand(100)
y = rand(100)

plt.plot(x,y);
#plt.show()

# %%
rand(100) #tutti compresi tra 0 ed 1, 100 numeri

# %%
#come vedere se le mie variabili sono uguali

x == y  #significa che i valori di x sono uguali ad y
len(y) #dimensione di y 
y.size #come sapere la dimensione dell'array, ed è monodimensionale
# Out:
# 100

# %%
plt.plot([10,20,30,40], '--r')  

#se non gli dico niente, per plottare prende il primo elemento della lista ed il suo indice corrispettivo
plt.ylabel('etichetta della y'); #cosa c'è scritto nella y
plt.xlabel('etichetta della x');
plt.title("Titolo del grafico");
plt.show()

# %%
plt.plot([0, 1, 2, 3],[4, 5, 6, 7], '--', marker='+', linewidth=0.3, color='yellow'); #il punto e virgola è per far sparire "l'errore grafico"(la scritta che viene fuori prima del grafico)
plt.plot([0, 1, 2, 3],[8, 10, 14, 19], marker='*', linewidth=0.3, color='blue')
plt.xlabel('label x');
#plt.show() #lo commentiamo perché sul notebook si vede in automatico, ma nel python normale no

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ob') #ob è il punto blu
plt.axis([0, 6, 0, 20]); #sono le scale di x ed y, infatti x è 0-6, y è 0-20
#plt.show()

# %%
plt.scatter([1, 2, 3, 4], [1, 4, 9, 16], c='g', alpha=0.9, marker=r'$\clubsuit$', )

# %%
x = np.linspace(0, 10, 100) #100 punti tra 0 e 10
y = np.exp(x) #y=f(x)
plt.plot(x,y);
#plt.show()
#sono sicuro che la length di x è uguale a quella di y perché lo fa la funzione

# %%
plt.figure(figsize=(10,7))
plt.plot(x,y)

# %%
x = np.linspace(0, 10, 100)
#f(t) = f(t+T)
plt.figure()
plt.plot(x, np.sin(x), '-', label='sin')
plt.plot(x, np.cos(x), '--', label='cos')
plt.title("Sin & cos")
plt.legend(loc='upper right')

# %% [markdown]
# Legenda posizione:
# *  upper right
# *  upper left
# *  lower left
# *  lower right
# *  right
# *  center left
# *  center right
# *  lower center
# *  upper center
# *  center

# %%
x = [i for i in range (101)]
y1 = [i**3 for i in ]
y2 = [i**2 for i ]

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend(['quadratic', 'cubic'], loc=0);

# %%
from random import sample
import random
#random.seed(667) #con random.seed vado a registrare/identificare che funzione random sto utilizzando, diventa un random fisso, serve per fare un confronto (eventi pilotati)
data = sample(range(1,1000), 100)
plt.hist(data);

# %% [markdown]
# I boxplot:
#
# *  **Rappresentano i percentili**
# *  **l'outlier è quando i data points eccedono di 3 volte l'SD**

# %% [markdown]
# Il dominio del grafico è da -5 a 5, quindi
# `x= np.linspace(-5,5, 100 (decido io))`

# %% [markdown]
# spines che prima stava a sinistra, mettilo al centro : `ax.spines['left'].set_position('center')`

# %%
subplot (2, 2, 1 ) #2 per due nella posizione 1
#cerca sublot figure(num,num,num)
